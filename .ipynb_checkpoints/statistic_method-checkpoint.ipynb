# %%
# -*- coding:utf-8 -*-
'''
@Author: LLC

@Date: 2018/10/11

@Description: Use statistic method to predict the CTR.
    
'''
# Out:
# '\n@Author: LLC\n\n@Date: 2018/10/11\n\n@Description: Use statistic method to predict the CTR.\n    \n'

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Dataset:
# Train, Test, Validation

# %%
test_df = pd.read_csv('..\data\oppo_train_valt_est_csv\oppo_round1_test_A_20180929.csv', encoding='UTF-8')
train_df = pd.read_csv('..\data\oppo_train_valt_est_csv\oppo_round1_train_20180929.csv', encoding='UTF-8')
vali_df = pd.read_csv('..\data\oppo_train_valt_est_csv\oppo_round1_vali_20180929.csv', encoding='UTF-8')

# %% [markdown]
# ## Poking the Dataset

# %%
train_df.describe(include='all')
# Out:
#          prefix                                           sup_dict    title  \
# count   2000000                                            2000000  1999987
# unique   156960                                             152560   249833
# top        汽车\t  {"汽车报价": "0.010", "汽车标志大全": "0.020", "汽车之家": "...     汽车之家
# freq      20066                                              20066    34857
# mean        NaN                                                NaN      NaN
# std         NaN                                                NaN      NaN
# min         NaN                                                NaN      NaN
# 25%         NaN                                                NaN      NaN
# 50%         NaN                                                NaN      NaN
# 75%         NaN                                                NaN      NaN
# max         NaN                                                NaN      NaN
#
#            type         click
# count   2000000  2.000000e+06
# unique       22           NaN
# top          百科           NaN
# freq     722096           NaN
# mean        NaN  3.720975e-01
# std         NaN  4.833643e-01
# min         NaN  0.000000e+00
# 25%         NaN  0.000000e+00
# 50%         NaN  0.000000e+00
# 75%         NaN  1.000000e+00
# max         NaN  1.000000e+00

# %% [markdown]
# ## Check the Nan Data

# %%
print(train_df.dtypes)
print(train_df.isna().sum())
print(test_df.isna().sum())
print(vali_df.isna().sum())
# Out:
# ['prefix' 'sup_dict' 'title' 'type' 'click']
# prefix      object
# sup_dict    object
# title       object
# type        object
# click        int64
# dtype: object
# prefix       0
# sup_dict     0
# title       13
# type         0
# click        0
# dtype: int64
# prefix      0
# sup_dict    0
# title       0
# type        0
# click       0
# dtype: int64
# prefix      0
# sup_dict    0
# title       0
# type        0
# click       0
# dtype: int64

# %% [markdown]
# Delete the Nan Value in Title.

# %%
# locs = np.where(train_df['title'].isna().values==True)
# train_df.iloc[locs[0], :]
train_df.dropna(subset = ['title'], inplace = True)
print(train_df.isna().sum())
# Out:
# prefix      0
# sup_dict    0
# title       0
# type        0
# click       0
# dtype: int64

# %%
train_df_vehice.describe(include='all')
# Out:
#        prefix                                           sup_dict  title  \
# count   20066                                              20066  20066
# unique      1                                                  1      2
# top      汽车\t  {"汽车报价": "0.010", "汽车标志大全": "0.020", "汽车之家": "...   汽车之家
# freq    20066                                              20066  19432
# mean      NaN                                                NaN    NaN
# std       NaN                                                NaN    NaN
# min       NaN                                                NaN    NaN
# 25%       NaN                                                NaN    NaN
# 50%       NaN                                                NaN    NaN
# 75%       NaN                                                NaN    NaN
# max       NaN                                                NaN    NaN
#
#          type         click assemble
# count   20066  20066.000000    20066
# unique      4           NaN        5
# top        应用           NaN  汽车之家 网站
# freq     7145           NaN     6864
# mean      NaN      0.353334      NaN
# std       NaN      0.478017      NaN
# min       NaN      0.000000      NaN
# 25%       NaN      0.000000      NaN
# 50%       NaN      0.000000      NaN
# 75%       NaN      1.000000      NaN
# max       NaN      1.000000      NaN

# %%
locs = np.where(train_df['prefix']=='汽车\t')
train_df_vehice = train_df.iloc[locs[0], :]
train_df_vehice['assemble'] = train_df_vehice.loc[:, 'title'] + ' ' +  train_df_vehice.loc[:, 'type']
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
train_df_vehice['assemble'].value_counts()
# Out:
# 汽车之家 网站      6864
# 汽车之家 应用      6511
# 汽车之家 快应用     6047
# 汽车报价大全 应用     634
# 汽车之家 百科        10
# Name: assemble, dtype: int64

# %% [markdown]
# # Get the Statistic Result

# %%
train_df['assemble'] = train_df['prefix'] + ' ' + train_df['title'] + ' ' + train_df['type']
train_df_click = train_df.loc[train_df['click']==1,:].groupby('assemble', as_index=False)
train_df_noclick = train_df.loc[train_df['click']==0,:].groupby('assemble', as_index=False)

# %% [markdown]
# 进行一些data frame的操作

# %%
click = train_df_click.count().loc[:, ['assemble', 'click']]
unclick = train_df_noclick.count().loc[:, ['assemble', 'click']]
result = pd.merge(click, unclick, how='outer', on=['assemble', 'assemble'])
result.rename(columns={'click_x':'click', 'click_y':'unclick'}, inplace = True)
result.fillna(0, inplace = True)
result['rate'] = result['click'] / (result['click'] + result['unclick'])
# Out:
#                            assemble  click  unclick      rate
# 0                   \t -谷氨酰转移酶增高 健康    1.0      2.0  0.333333
# 1                    \t .. (你好.) 音乐    1.0      0.0  1.000000
# 2                        \t 1风湿热 健康   31.0     69.0  0.310000
# 3                     \t Anam. - 音乐    1.0      0.0  1.000000
# 4       \t HIRAMEKI!. Peace. ()v 音乐    1.0      0.0  1.000000
# 5                \t So. It. Goes 音乐    6.0     14.0  0.300000
# 6                   \t and. LOVE 百科   17.0      6.0  0.739130
# 7            \t co. 60照射和射线照射的区别 知道    1.0      1.0  0.500000
# 8                         \t ios 音乐    2.0      2.0  0.500000
# 9                     \t lol按键说明 知道    3.0     10.0  0.230769
# 10                \t x^3/1+x^2dx 知道    2.0      3.0  0.400000
# 11              \t 一般情况下的一般是什么意思 知道    1.0      0.0  1.000000
# 12               \t 作文要放寒假了%2C我想 知道    1.0      0.0  1.000000
# 13                        \t 却造句 知道    2.0      5.0  0.285714
# 14                          \t 囧 百科   72.0     60.0  0.545455
# 15                      \t 如何解决呀 健康    1.0      0.0  1.000000
# 16                        \t 工作室 百科    4.0     22.0  0.153846
# 17                        \t 总牙疼 健康   13.0     21.0  0.382353
# 18                        \t 恋時忘 音乐    1.0      0.0  1.000000
# 19                          \t 殇 百科   64.0     31.0  0.673684
# 20                        \t 爱无限 百科    4.0      9.0  0.307692
# 21                        \t 甲沟炎 健康    1.0     13.0  0.071429
# 22                 \t 等于多少小数点后十位 知道    1.0      0.0  1.000000
# 23                  \t 絆Infinity 音乐   25.0     29.0  0.462963
# 24                \t 经期要延迟几天才能知道 健康    1.0      0.0  1.000000
# 25                         \t 肚子 健康    3.0     13.0  0.187500
# 26                       \t 赶尸真相 影视   29.0     42.0  0.408451
# 27                        \t 这节奏 音乐    9.0      4.0  0.692308
# 28                    \t 骜这个字怎么读 知道   21.0     52.0  0.287671
# 29                       \t 1风湿热 健康    1.0      0.0  1.000000
# ...                             ...    ...      ...       ...
# 329215  龟头又红又\t 龟头又红又痒用什么药张家港哪里治 健康    0.0      1.0  0.000000
# 329216        龟头和包皮\t 成都龟头和包皮起红点 健康    0.0      1.0  0.000000
# 329217          龟头尖\t 龟头尖锐湿疣能治愈吗 健康    0.0      1.0  0.000000
# 329218      龟头尖锐湿疣\t 得了龟头尖锐湿疣怎么治 健康    0.0      2.0  0.000000
# 329219      龟头尖锐湿疣\t 成都锦江区龟头尖锐湿疣 健康    0.0      2.0  0.000000
# 329220        龟头掉\t 广州男人龟头掉皮怎么回事 健康    0.0      1.0  0.000000
# 329221         龟头有水\t 龟头有水泡要怎样治疗 健康    0.0      1.0  0.000000
# 329222                龟头炎图片\t 图曰 应用    0.0      1.0  0.000000
# 329223          龟头痒怎么\t 男人龟头痒怎么办 健康    0.0      1.0  0.000000
# 329224         龟头瘙痒\t 哪些原因引起龟头瘙痒 健康    0.0      1.0  0.000000
# 329225         龟头瘙痒\t 龟头瘙痒怎么治疗最好 健康    0.0      1.0  0.000000
# 329226         龟头糜烂\t 南京鼓楼区龟头糜烂呢 健康    0.0      1.0  0.000000
# 329227               龟头红肿\t 龟头红肿 百科    0.0      3.0  0.000000
# 329228        龟头起痘痘\t 成都新都区龟头起痘痘 健康    0.0      1.0  0.000000
# 329229     龟头边缘发\t 龟头边缘发紫不会是阴茎癌吧 健康    0.0      1.0  0.000000
# 329230                  龟峰\t 灵龟峰 百科    0.0      1.0  0.000000
# 329231            龟峰山\t 龟峰山风景名胜区 百科    0.0      1.0  0.000000
# 329232                  龟板\t 海龟板 百科    0.0      2.0  0.000000
# 329233                  龟灵\t 龟灵膏 百科    0.0      1.0  0.000000
# 329234               龟甲\t 龟甲怎么食用 健康    0.0      1.0  0.000000
# 329235     龟甲养\t 龟甲养阴片治疗阴虚腰痛效果好吗 健康    0.0      2.0  0.000000
# 329236    龟甲养阴\t 龟甲养阴片治疗阴虚腰痛效果好吗 健康    0.0      1.0  0.000000
# 329237          龟背竹\t 龟背竹多长时间能长大 知道    0.0     16.0  0.000000
# 329238             龟苓\t 自制龟苓膏的做法 菜谱    0.0      4.0  0.000000
# 329239                龟苓膏\t 前程无忧 应用    0.0      9.0  0.000000
# 329240                  龟苓膏\t 返利 应用    0.0      3.0  0.000000
# 329241         龟鹿二仙膏\t 可以吃龟鹿二仙膏吗 健康    0.0      1.0  0.000000
# 329242             龟鹿二仙膏\t 龟鹿二仙膏 健康    0.0      1.0  0.000000
# 329243                  龟龙\t 龟龙变 百科    0.0      1.0  0.000000
# 329244                  龟龙\t 龟龙变 阅读    0.0      1.0  0.000000
#
# [329245 rows x 4 columns]

# %%
vali_df['assemble'] = vali_df['prefix'] + ' ' + vali_df['title'] + ' ' + vali_df['type']
